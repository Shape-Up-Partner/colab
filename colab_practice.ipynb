# %% [markdown]
# <a href="https://colab.research.google.com/github/Shape-Up-Partner/colab/blob/master/colab_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XLNet IMDB movie review classification project
#
# This notebook is for classifying the [imdb sentiment dataset](https://ai.stanford.edu/~amaas/data/sentiment/).  It will be easy to edit this notebook in order to run all of the classification tasks referenced in the [XLNet paper](https://arxiv.org/abs/1906.08237). Whilst you cannot expect to obtain the state-of-the-art results in the paper on a GPU, this model will still score very highly.

# %% [markdown]
# ## Setup
# Install dependencies

# %%
! pip install sentencepiece
# this is unique one
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/00/95/7f357995d5eb1131aa2092096dca14a6fc1b1d2860bd99c22a612e1d1019/sentencepiece-0.1.82-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 45.2MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.82

# %% [markdown]
# Download the pretrained XLNet model and unzip

# %%
# only needs to be done once
! wget https://storage.googleapis.com/xlnet/released_models/cased_L-24_H-1024_A-16.zip
! unzip cased_L-24_H-1024_A-16.zip
# Out:
# --2019-08-02 09:07:32--  https://storage.googleapis.com/xlnet/released_models/cased_L-24_H-1024_A-16.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.128, 2404:6800:4003:c00::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1338042341 (1.2G) [application/zip]
# Saving to: ‘cased_L-24_H-1024_A-16.zip’
#
# cased_L-24_H-1024_A 100%[===================>]   1.25G  50.2MB/s    in 21s
#
# 2019-08-02 09:07:54 (59.9 MB/s) - ‘cased_L-24_H-1024_A-16.zip’ saved [1338042341/1338042341]
#
# Archive:  cased_L-24_H-1024_A-16.zip
#    creating: xlnet_cased_L-24_H-1024_A-16/
#   inflating: xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt.index
#   inflating: xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt.data-00000-of-00001
#   inflating: xlnet_cased_L-24_H-1024_A-16/spiece.model
#   inflating: xlnet_cased_L-24_H-1024_A-16/xlnet_model.ckpt.meta
#   inflating: xlnet_cased_L-24_H-1024_A-16/xlnet_config.json

# %% [markdown]
# Download extract the imdb dataset - surpessing output

# %%
! wget http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
! tar zxf aclImdb_v1.tar.gz
# Out:
# --2019-08-02 09:08:17--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  16.3MB/s    in 8.8s
#
# 2019-08-02 09:08:26 (9.15 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# Git clone XLNet repo for access to run_classifier and the rest of the xlnet module

# %%
! git clone https://github.com/zihangdai/xlnet.git
# Out:
# Cloning into 'xlnet'...
# remote: Enumerating objects: 118, done.
# remote: Total 118 (delta 0), reused 0 (delta 0), pack-reused 118
# Receiving objects: 100% (118/118), 135.28 KiB | 273.00 KiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %% [markdown]
# ## Define Variables
# Define all the dirs: data, xlnet scripts & pretrained model.
# If you would like to save models then you can authenticate a GCP account and use that for the OUTPUT_DIR & CHECKPOINT_DIR - you will need a large amount storage to fix these models.
#
# Alternatively it is easy to integrate a google drive account, checkout this guide for [I/O in colab](https://colab.research.google.com/notebooks/io.ipynb) but rememeber these will take up a large amount of storage.

# %%
SCRIPTS_DIR = 'xlnet' #@param {type:"string"}
DATA_DIR = 'aclImdb' #@param {type:"string"}
OUTPUT_DIR = 'proc_data/imdb' #@param {type:"string"}
PRETRAINED_MODEL_DIR = 'xlnet_cased_L-24_H-1024_A-16' #@param {type:"string"}
CHECKPOINT_DIR = 'exp/imdb' #@param {type:"string"}

# %% [markdown]
# ## Run Model
# This will set off the fine tuning of XLNet. There are a few things to note here:
#
#
# 1.   This script will train and evaluate the model
# 2.   This will store the results locally on colab and will be lost when you are disconnected from the runtime
# 3.   This uses the large version of the model (base not released presently)
# 4.   We are using a max seq length of 128 with a batch size of 8 please refer to the [README](https://github.com/zihangdai/xlnet#memory-issue-during-finetuning) for why this is.
# 5. This will take approx 4hrs to run on GPU.

# %%
train_command = "python xlnet/run_classifier.py \
  --do_train=True \
  --do_eval=True \
  --eval_all_ckpt=True \
  --task_name=imdb \
  --data_dir="+DATA_DIR+" \
  --output_dir="+OUTPUT_DIR+" \
  --model_dir="+CHECKPOINT_DIR+" \
  --uncased=False \
  --spiece_model_file="+PRETRAINED_MODEL_DIR+"/spiece.model \
  --model_config_path="+PRETRAINED_MODEL_DIR+"/xlnet_config.json \
  --init_checkpoint="+PRETRAINED_MODEL_DIR+"/xlnet_model.ckpt \
  --max_seq_length=128 \
  --train_batch_size=8 \
  --eval_batch_size=8 \
  --num_hosts=1 \
  --num_core_per_host=1 \
  --learning_rate=2e-5 \
  --train_steps=4000 \
  --warmup_steps=500 \
  --save_steps=500 \
  --iterations=500"

! {train_command}
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 09:08:53.736016 139936332392320 deprecation_wrapper.py:119] From /content/xlnet/model_utils.py:295: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0802 09:08:53.746151 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:855: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0802 09:08:53.746704 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:637: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0802 09:08:53.746845 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:637: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0802 09:08:53.746962 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:661: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0802 09:08:53.747130 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:662: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W0802 09:08:53.800800 139936332392320 deprecation_wrapper.py:119] From /content/xlnet/model_utils.py:27: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0802 09:08:53.800988 139936332392320 deprecation_wrapper.py:119] From /content/xlnet/model_utils.py:36: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# I0802 09:08:53.801080 139936332392320 model_utils.py:36] Single device mode.
# W0802 09:08:55.851917 139936332392320 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# I0802 09:08:55.852587 139936332392320 estimator.py:209] Using config: {'_model_dir': 'exp/imdb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 0, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f453c617390>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=500, num_shards=1, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2), '_cluster': None}
# W0802 09:08:55.852823 139936332392320 model_fn.py:630] Estimator's model_fn (<function get_model_fn.<locals>.model_fn at 0x7f453c615840>) includes params argument, but params are not passed to Estimator.
# I0802 09:08:55.853677 139936332392320 run_classifier.py:703] Use tfrecord file proc_data/imdb/spiece.model.len-128.train.tf_record
# W0802 09:08:55.853798 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:312: The name tf.gfile.ListDirectory is deprecated. Please use tf.io.gfile.listdir instead.
#
# W0802 09:08:55.869925 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:316: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# I0802 09:08:58.706037 139936332392320 run_classifier.py:707] Num of train samples: 25000
# I0802 09:08:58.706325 139936332392320 run_classifier.py:405] Create new tfrecord proc_data/imdb/spiece.model.len-128.train.tf_record.
# W0802 09:08:58.706474 139936332392320 deprecation_wrapper.py:119] From xlnet/run_classifier.py:407: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 09:09:40.155588 139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 09:09:40.155702 139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 09:09:40.155803 139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.155907 139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.155997 139936332392320 model_utils.py:91]   name = model/transformer/layer_12/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.156120 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.156225 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.156351 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.156463 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.156560 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.156658 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.156751 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.156843 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 09:09:40.156939 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 09:09:40.157031 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 09:09:40.157154 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.157247 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.157339 139936332392320 model_utils.py:91]   name = model/transformer/layer_13/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.157430 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.157537 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.157639 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.157747 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.157846 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.157945 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.158074 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.158184 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 09:09:40.158297 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 09:09:40.158391 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 09:09:40.158488 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.158601 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.158699 139936332392320 model_utils.py:91]   name = model/transformer/layer_14/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.158804 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.158900 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.158998 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.159133 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.159237 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.159340 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.159431 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.159521 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 09:09:40.159617 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 09:09:40.159711 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 09:09:40.159806 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.159899 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.159993 139936332392320 model_utils.py:91]   name = model/transformer/layer_15/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 09:09:40.160098 139936332392320 model_utils.py:91]   name = model/transformer/layer_16/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.160210 139936332392320 model_utils.py:91]   name = model/transformer/layer_16/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 09:09:40.160317 139936332392320 model_utils.py:91]   name = model/transformer/layer_16/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# ...
# I0802 12:28:37.502893 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.502992 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.503108 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.503210 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.503317 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.503410 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.503502 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 12:28:37.503599 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 12:28:37.503690 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 12:28:37.503786 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.503879 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.503968 139936332392320 model_utils.py:91]   name = model/transformer/layer_19/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.504071 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.504175 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.504281 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.504381 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.504480 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.504579 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.504672 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.504763 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 12:28:37.504861 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 12:28:37.504951 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 12:28:37.505047 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.505188 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.505287 139936332392320 model_utils.py:91]   name = model/transformer/layer_20/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.505379 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.505478 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.505575 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.505672 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.505770 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.505867 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.505957 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.506082 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 12:28:37.506187 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 12:28:37.506298 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 12:28:37.506396 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.506506 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.506600 139936332392320 model_utils.py:91]   name = model/transformer/layer_21/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.506723 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.506826 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.506934 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.507031 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.507146 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.507244 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.507347 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.507440 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 12:28:37.507535 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 12:28:37.507627 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 12:28:37.507725 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.507816 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.507905 139936332392320 model_utils.py:91]   name = model/transformer/layer_22/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.507996 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/q/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.508111 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/k/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.508209 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/v/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.508315 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/r/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.508414 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/o/kernel:0, shape = (1024, 16, 64), *INIT_FROM_CKPT*
# I0802 12:28:37.508511 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.508602 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/rel_attn/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.508693 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/layer_1/kernel:0, shape = (1024, 4096), *INIT_FROM_CKPT*
# I0802 12:28:37.508788 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/layer_1/bias:0, shape = (4096,), *INIT_FROM_CKPT*
# I0802 12:28:37.508883 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/layer_2/kernel:0, shape = (4096, 1024), *INIT_FROM_CKPT*
# I0802 12:28:37.508979 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/layer_2/bias:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.509084 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/LayerNorm/beta:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.509177 139936332392320 model_utils.py:91]   name = model/transformer/layer_23/ff/LayerNorm/gamma:0, shape = (1024,), *INIT_FROM_CKPT*
# I0802 12:28:37.509276 139936332392320 model_utils.py:91]   name = model/sequnece_summary/summary/kernel:0, shape = (1024, 1024)
# I0802 12:28:37.509373 139936332392320 model_utils.py:91]   name = model/sequnece_summary/summary/bias:0, shape = (1024,)
# I0802 12:28:37.509465 139936332392320 model_utils.py:91]   name = model/classification_imdb/logit/kernel:0, shape = (1024, 2)
# I0802 12:28:37.509591 139936332392320 model_utils.py:91]   name = model/classification_imdb/logit/bias:0, shape = (2,)
# I0802 12:28:37.539801 139936332392320 estimator.py:1147] Done calling model_fn.
# I0802 12:28:37.557284 139936332392320 evaluation.py:255] Starting evaluation at 2019-08-02T12:28:37Z
# I0802 12:28:38.266908 139936332392320 monitored_session.py:240] Graph was finalized.
# 2019-08-02 12:28:38.267561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-02 12:28:38.267841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-02 12:28:38.297666: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-02 12:28:38.297737: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-02 12:28:38.297760: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-02 12:28:38.297781: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-02 12:28:38.297804: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-02 12:28:38.297823: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-02 12:28:38.297843: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-02 12:28:38.297960: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-02 12:28:38.298315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-02 12:28:38.298518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-02 12:28:38.298564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-02 12:28:38.298577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-02 12:28:38.298587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-02 12:28:38.298741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-02 12:28:38.299013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-02 12:28:38.299272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# I0802 12:28:38.300303 139936332392320 saver.py:1280] Restoring parameters from exp/imdb/model.ckpt-4000
# I0802 12:28:49.351316 139936332392320 session_manager.py:500] Running local_init_op.
# I0802 12:28:49.487541 139936332392320 session_manager.py:502] Done running local_init_op.
# I0802 12:30:28.637130 139936332392320 evaluation.py:167] Evaluation [312/3125]
# I0802 12:32:02.087376 139936332392320 evaluation.py:167] Evaluation [624/3125]
# I0802 12:33:35.853395 139936332392320 evaluation.py:167] Evaluation [936/3125]
# I0802 12:35:09.558698 139936332392320 evaluation.py:167] Evaluation [1248/3125]
# I0802 12:36:43.311399 139936332392320 evaluation.py:167] Evaluation [1560/3125]
# I0802 12:38:17.203966 139936332392320 evaluation.py:167] Evaluation [1872/3125]
# I0802 12:39:51.063522 139936332392320 evaluation.py:167] Evaluation [2184/3125]
# I0802 12:41:25.031539 139936332392320 evaluation.py:167] Evaluation [2496/3125]
# I0802 12:42:59.464201 139936332392320 evaluation.py:167] Evaluation [2808/3125]
# I0802 12:44:33.977716 139936332392320 evaluation.py:167] Evaluation [3120/3125]
# I0802 12:44:35.486810 139936332392320 evaluation.py:167] Evaluation [3125/3125]
# I0802 12:44:35.756490 139936332392320 evaluation.py:275] Finished evaluation at 2019-08-02-12:44:35
# I0802 12:44:35.756783 139936332392320 estimator.py:2039] Saving dict for global step 4000: eval_accuracy = 0.92172, eval_loss = 0.30752438, global_step = 4000, loss = 0.30752438
# I0802 12:44:35.758068 139936332392320 estimator.py:2099] Saving 'checkpoint_path' summary for global step 4000: exp/imdb/model.ckpt-4000
# I0802 12:44:35.758644 139936332392320 run_classifier.py:786] ================================================================================
# I0802 12:44:35.758793 139936332392320 run_classifier.py:790] Eval result | eval_accuracy 0.921720027923584 | eval_loss 0.3075243830680847 | global_step 4000 | loss 0.3075243830680847 | path exp/imdb/model.ckpt-4000 | step 4000 |
# I0802 12:44:35.758885 139936332392320 run_classifier.py:795] ================================================================================
# I0802 12:44:35.758965 139936332392320 run_classifier.py:799] Best result | eval_accuracy 0.921720027923584 | eval_loss 0.3075243830680847 | global_step 4000 | loss 0.3075243830680847 | path exp/imdb/model.ckpt-4000 | step 4000 |

# %% [markdown]
# ## Running & Results
# These are the results that I got from running this experiment
# ### Params
# *    --max_seq_length=128 \
# *    --train_batch_size= 8
#
# ### Times
# *   Training: 1hr 11mins
# *   Evaluation: 2.5hr
#
# ### Results
# *  Most accurate model on final step
# *  Accuracy: 0.92416, eval_loss: 0.31708

# %% [markdown]
# ### Model
#
# *   The trained model checkpoints can be found in 'exp/imdb'
